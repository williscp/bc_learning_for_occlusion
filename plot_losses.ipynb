# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
bc_loss = np.load('output/bc_resnet_train_loss.npy')
bc_prop_loss = np.load('output/bc_prop_resnet_train_loss.npy')
bc_vh_loss = np.load('output/bc_vh_resnet_train_loss.npy')
resnet_loss = np.load('output/resnet_train_loss.npy')

# %%
plt.plot(bc_loss, label='Linear')
plt.plot(bc_prop_loss, label='BC+')
plt.plot(bc_vh_loss, label='VH-BC+')
plt.plot(resnet_loss, label='None')
plt.legend()
